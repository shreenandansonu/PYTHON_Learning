# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
#plot the x cordinate.
g=9.8
accelerationx=np.zeros(21)
accelerationy=np.zeros(21)
angles = np.array([0, 20, 40, 60, 80, 90, 100, 120, 140, 160, 180,200, 220, 240, 260, 270, 280, 300, 320, 340, 360])
for i in range(21):
    accelerationx[i]=g*np.cos(angles[i])
    accelerationy[i]=g*np.sin(angles[i])
voltagesx = np.array([75, 500, 850, 1140, 1210, 1250, 1210, 980, 675, 350, 20, 540, 790, 1120, 1280, 1260, 1250, 1050, 750, 350, 20])
voltagesy = np.array([16.6, 60.2, 240, 550, 930, 1100, 1240, 1620, 1860, 2010, 2060, 2000, 1740, 1570, 1130, 980, 800, 490, 200, 20, 30])
# voltagesz = np.array([1220, 770, 390, 130, 10, 7, 30, 180, 500, 880, 1290, 1770, 2080, 2330, 2450, 2500, 2450, 2320, 2010, 1650, 1250])
plt.plot(accelerationx,voltagesx)
plt.plot(accelerationy,voltagesy)
# plt.plot(accelerationz,voltagesz, angles)
